# %%
import pandas as pd

# %%
knee_proms_raw = pd.read_parquet("knee-provider.parquet")
knee_proms_raw.head()
# Out:
#   provider_code         procedure  revision_flag     year age_band  gender  \
# 0         ADP02  Knee Replacement              0  2018/19      NaN     NaN
# 1         ADP02  Knee Replacement              0  2018/19      NaN     NaN
# 2         ADP02  Knee Replacement              0  2018/19      NaN     NaN
# 3         ADP02  Knee Replacement              0  2018/19      NaN     NaN
# 4         ADP02  Knee Replacement              0  2018/19      NaN     NaN
#
#    t0_assisted  t0_assisted_by  t0_symptom_period  t0_previous_surgery  ...  \
# 0            2               0                  2                    2  ...
# 1            2               0                  2                    2  ...
# 2            2               0                  2                    2  ...
# 3            2               0                  2                    2  ...
# 4            1               0                  3                    2  ...
#
# ...

# %%
knee_proms_outcome_col = knee_proms_raw[['t1_eq_vas']]

knee_proms_outcome_col
# Out:
#         t1_eq_vas
# 0             999
# 1              95
# 2              98
# 3              60
# 4              80
# ...           ...
# 139231         83
# 139232         90
# 139233         85
# 139234         50
# 139235         80
#
# [139236 rows x 1 columns]

# %%
knee_proms_available_prior_surg = knee_proms_raw.drop(list(knee_proms_raw.filter(regex='t1')), axis=1)

# %%
knee_proms_final = pd.merge(
    left=knee_proms_available_prior_surg,
    right=knee_proms_outcome_col,
    left_index=True,
    right_index=True)

# %%
knee_proms_final.to_csv("../teaching_notebooks/knee_proms_processed.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 knee_proms_final.to_csv("../teaching_notebooks/knee_proms_processed.csv", index=False)
#
# File c:\Users\Sammi\Anaconda3\envs\ml\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
# ...
